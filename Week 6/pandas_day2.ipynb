# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Thinkbiz\\Python AI training\\Week 6\\Chocolate Sales (2).csv')

# %%
print(df.head())
# Out:
#      Sales Person    Country              Product        Date      Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04/01/2022   $5,320.00
# 1     Van Tuxwell      India        85% Dark Bars  01/08/2022   $7,896.00
# 2    Gigi Bohling      India  Peanut Butter Cubes  07/07/2022   $4,501.00
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27/04/2022  $12,726.00
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24/02/2022  $13,685.00
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
print(df.to_string())
# Out:
#              Sales Person      Country               Product        Date      Amount  Boxes Shipped
# 0          Jehu Rudeforth           UK       Mint Chip Choco  04/01/2022   $5,320.00            180
# 1             Van Tuxwell        India         85% Dark Bars  01/08/2022   $7,896.00             94
# 2            Gigi Bohling        India   Peanut Butter Cubes  07/07/2022   $4,501.00             91
# 3            Jan Morforth    Australia   Peanut Butter Cubes  27/04/2022  $12,726.00            342
# 4          Jehu Rudeforth           UK   Peanut Butter Cubes  24/02/2022  $13,685.00            184
# 5             Van Tuxwell        India    Smooth Sliky Salty  06/06/2022   $5,376.00             38
# 6              Oby Sorrel           UK       99% Dark & Pure  25/01/2022  $13,685.00            176
# 7         Gunar Cockshoot    Australia           After Nines  24/03/2022   $3,080.00             73
# ...

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3282 entries, 0 to 3281
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   3282 non-null   object
#  1   Country        3282 non-null   object
#  2   Product        3282 non-null   object
#  3   Date           3282 non-null   object
#  4   Amount         3282 non-null   object
#  5   Boxes Shipped  3282 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 154.0+ KB
# None

# %%
df.dropna(inplace = True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3282 entries, 0 to 3281
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   3282 non-null   object
#  1   Country        3282 non-null   object
#  2   Product        3282 non-null   object
#  3   Date           3282 non-null   object
#  4   Amount         3282 non-null   object
#  5   Boxes Shipped  3282 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 154.0+ KB
# None

# %%
print(df.head())
# Out:
#      Sales Person    Country              Product        Date      Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04/01/2022   $5,320.00
# 1     Van Tuxwell      India        85% Dark Bars  01/08/2022   $7,896.00
# 2    Gigi Bohling      India  Peanut Butter Cubes  07/07/2022   $4,501.00
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27/04/2022  $12,726.00
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24/02/2022  $13,685.00
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
df.dropna(subset=['Date'], inplace = True)

# %%
for x in df.index:
  if df.loc[x, "Boxes Shipped"] <12:
    df.loc[x, "Boxes Shipped"] = 12

# %%
print(df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3277    False
# 3278    False
# 3279    False
# 3280    False
# 3281    False
# Length: 3282, dtype: bool

# %%
#loc function is used to access a group of rows and columns by labels or a boolean array.

df.loc[5, "Boxes Shipped"] = 10
print(df.loc[5])
# Out:
# Sales Person            Van Tuxwell
# Country                       India
# Product          Smooth Sliky Salty
# Date                     06/06/2022
# Amount                    $5,376.00
# Boxes Shipped                    10
# Name: 5, dtype: object

# %%
#max boxes shipped
max_boxes_shipped = df["Boxes Shipped"].max()
print(max_boxes_shipped)
# Out:
# 778

# %%
print(df['Amount'].dtype)
# Out:
# object

# %%
df["Amount"] = df["Amount"].str.replace("\\$|,", "", regex=True).astype(float)

# %%
df["Amount"].dtype
# Out:
# dtype('float64')

# %%
display(df.loc[(df['Amount']>=1000.00) & (df['Boxes Shipped'] >= 500),
                    ['Sales Person', 'Boxes Shipped']])
# Out:
#              Sales Person  Boxes Shipped
# 39       Karlen McCaffrey            581
# 109          Jan Morforth            520
# 121         Kelci Walkden            547
# 171         Kelci Walkden            520
# 340           Kaine Padly            554
# 458       Roddy Speechley            543
# 672        Jehu Rudeforth            512
# 692        Dotty Strutley            508
# 730      Karlen McCaffrey            708
# 765       Gunar Cockshoot            524
# 769      Karlen McCaffrey            597
# 852        Marney O'Breen            614
# 875        Beverie Moffet            518
# 978        Mallorie Waber            539
# 1028          Van Tuxwell            709
# 1070           Oby Sorrel            591
# 1133     Karlen McCaffrey            583
# 1191        Kelci Walkden            509
# 1215        Kelci Walkden            570
# 1244       Camilla Castle            509
# 1265        Kelci Walkden            531
# 1434          Kaine Padly            599
# ...
