# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Thinkbiz\\Python AI training\\Week 6\\imdb_top_1000.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
print(df.head(5))
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.isnull()
# Out:
#      Poster_Link  Series_Title  Released_Year  Certificate  Runtime  Genre  \
# 0          False         False          False        False    False  False
# 1          False         False          False        False    False  False
# 2          False         False          False        False    False  False
# 3          False         False          False        False    False  False
# 4          False         False          False        False    False  False
# ..           ...           ...            ...          ...      ...    ...
# 995        False         False          False        False    False  False
# 996        False         False          False        False    False  False
# 997        False         False          False        False    False  False
# 998        False         False          False         True    False  False
# 999        False         False          False         True    False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
 #df.dropna({"Series_Title"}(inplace = True))

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB
# None

# %%
df['Series_Title'] = df['Series_Title'].astype('str')

# %%
df.dropna(subset=['Series_Title'])
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df = df[df['Meta_score'].notna() & (df['Meta_score'] != "")]

# %%
df.isnull().sum()
# Out:
# Poster_Link       0
# Series_Title      0
# Released_Year     0
# Certificate      56
# Runtime           0
# Genre             0
# IMDB_Rating       0
# Overview          0
# Meta_score        0
# Director          0
# Star1             0
# Star2             0
# Star3             0
# Star4             0
# No_of_Votes       0
# Gross            93
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.iloc[0].Genre
# Out:
# 'Drama'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 843 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    843 non-null    object
#  1   Series_Title   843 non-null    object
#  2   Released_Year  843 non-null    object
#  3   Certificate    787 non-null    object
#  4   Runtime        843 non-null    object
#  5   Genre          843 non-null    object
#  6   IMDB_Rating    843 non-null    float64
#  7   Overview       843 non-null    object
#  8   Meta_score     843 non-null    float64
#  9   Director       843 non-null    object
#  10  Star1          843 non-null    object
#  11  Star2          843 non-null    object
#  12  Star3          843 non-null    object
#  13  Star4          843 non-null    object
#  14  No_of_Votes    843 non-null    int64
#  15  Gross          750 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 112.0+ KB

# %%
df.isnull().sum()
# Out:
# Poster_Link       0
# Series_Title      0
# Released_Year     0
# Certificate      56
# Runtime           0
# Genre             0
# IMDB_Rating       0
# Overview          0
# Meta_score        0
# Director          0
# Star1             0
# Star2             0
# Star3             0
# Star4             0
# No_of_Votes       0
# Gross            93
# dtype: int64

# %%
df['Star1'] = df['Star1'].astype('str')
# Out:
# C:\Users\Thinkbiz\AppData\Local\Temp\ipykernel_2548\2869888936.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Star1'] = df['Star1'].astype('str')

# %%
df['Star2'] = df['Star2'].astype('str')
# Out:
# C:\Users\Thinkbiz\AppData\Local\Temp\ipykernel_2548\2025471744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Star2'] = df['Star2'].astype('str')

# %%
df['Star3'] = df['Star3'].astype('str')
# Out:
# C:\Users\Thinkbiz\AppData\Local\Temp\ipykernel_2548\2636463503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Star3'] = df['Star3'].astype('str')

# %%
df['Star_Cast'] = df[['Star1','Star2','Star3','Star4']].apply(
    lambda row: ', '.join([str(x).strip() for x in row if pd.notna(x) and str(x).strip() != '']),
    axis=1
)
# Out:
# C:\Users\Thinkbiz\AppData\Local\Temp\ipykernel_2548\4034393201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Star_Cast'] = df[['Star1','Star2','Star3','Star4']].apply(

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.drop(columns=['Star1', 'Star2', 'Star3'], inplace=True)
# Out:
# C:\Users\Thinkbiz\AppData\Local\Temp\ipykernel_2548\1635027921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Star1', 'Star2', 'Star3'], inplace=True)

# %%
df.drop(columns=['Star4'], inplace=True)
# Out:
# C:\Users\Thinkbiz\AppData\Local\Temp\ipykernel_2548\2299030171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Star4'], inplace=True)

# %%
# df['Star_Cast'] = df[['Star_Cast','Star4']].apply(
#     lambda row: ', '.join([str(x).strip() for x in row if pd.notna(x) and str(x).strip() != '']),
#     axis=1
#

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df['Certificate'] = df['Certificate'].astype('str')
# Out:
# C:\Users\Thinkbiz\AppData\Local\Temp\ipykernel_2548\1489420760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Certificate'] = df['Certificate'].astype('str')

# %%
top = df.dropna(subset=['Series_Title', 'IMDB_Rating']).loc[(df['No_of_Votes'] >= 5000) & (df['IMDB_Rating'] >= 5.0)].sort_values(['IMDB_Rating', 'No_of_Votes'], ascending=[False, False]).head(20)

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.groupby('Series_Title')
print(df.groupby('Series_Title').groups)
# Out:
# {'(500) Days of Summer': [754], '12 Angry Men': [4], '12 Years a Slave': [215], '1917': [84], '2001: A Space Odyssey': [114], '21 Grams': [938], '25th Hour': [941], '28 Days Later...': [943], '3 Idiots': [64], '300': [928], '3:10 to Yuma': [774], '4 luni, 3 saptamâni si 2 zile': [492], '50/50': [907], '8½': [432], 'A Beautiful Mind': [159], 'A Bronx Tale': [664], 'A Christmas Story': [531], 'A Clockwork Orange': [113], 'A Few Good Men': [824], 'A Hard Day's Night': [994], 'A Little Princess': [813], 'A Man for All Seasons': [858], 'A Star Is Born': [903], 'A Streetcar Named Desire': [447], 'About Time': [593], 'Ace in the Hole': [307], 'Adams æbler': [630], 'Adaptation.': [789], 'After Hours': [836], 'Ah-ga-ssi': [199], 'Airplane!': [842], 'Aladdin': [399], 'Alien': [75], 'Aliens': [106], 'All About Eve': [190], 'All Quiet on the Western Front': [461], 'All That Jazz': [534], 'All the President's Men': [536], 'Almost Famous': [514], 'Amadeus': [107], 'American Beauty': [98], 'America
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 843 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    843 non-null    object
#  1   Series_Title   843 non-null    object
#  2   Released_Year  843 non-null    object
#  3   Certificate    843 non-null    object
#  4   Runtime        843 non-null    object
#  5   Genre          843 non-null    object
#  6   IMDB_Rating    843 non-null    float64
#  7   Overview       843 non-null    object
#  8   Meta_score     843 non-null    float64
#  9   Director       843 non-null    object
#  10  No_of_Votes    843 non-null    int64
#  11  Gross          750 non-null    object
#  12  Star_Cast      843 non-null    object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 92.2+ KB

# %%
df.aggregate({"No_of_Votes":['sum']})
# Out:
#      No_of_Votes
# sum    264016757

# %%
df.aggregate({"No_of_Votes":['min']})
# Out:
#      No_of_Votes
# min        25198

# %%
mappings = {
    'A': 'Adult',}

# %%
df['type_name'] = df['Certificate'].map(mappings)
# Out:
# C:\Users\Thinkbiz\AppData\Local\Temp\ipykernel_2548\2156658929.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['type_name'] = df['Certificate'].map(mappings)

# %%
print(df['type_name'])
# Out:
# 0      Adult
# 1      Adult
# 2        NaN
# 3      Adult
# 4        NaN
#        ...
# 995    Adult
# 996      NaN
# 997      NaN
# 998      NaN
# 999      NaN
# Name: type_name, Length: 843, dtype: object

# %%
import datetime

# %%
from datetime import date

# %%
# Creating a Timestamp object
timestamp = pd.Timestamp('2023-10-04 15:30:00')

# Extracting the year from the Timestamp
year = timestamp.year

# Printing the extracted year
print(year)

# Extracting the month from the Timestamp
month = timestamp.month

# Printing the extracted month
print(month)

# Extracting the day from the Timestamp
day = timestamp.day

# Printing the extracted day
print(day)
# Out:
# 2023
# 10
# 4

# %%
# Extracting the hour from the Timestamp
hour = timestamp.hour

# Printing the extracted hour
print(hour)

# Extracting the minute from the Timestamp
minute = timestamp.minute

# Printing the extracted minute
print(minute)
# Extracting the weekday from the Timestamp
weekday = timestamp.weekday()

# Printing the extracted weekday
print(weekday)

# Extracting the quarter from the Timestamp
quarter = timestamp.quarter

# Printing the extracted quarter
print(quarter)
# Out:
# 15
# 30
# 2
# 4

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# No_of_Votes        int64
# Gross             object
# Star_Cast         object
# type_name         object
# dtype: object

# %%
df["Runtime"] = df["Runtime"].str.replace("min", "", regex=True).astype(float)
# Out:
# C:\Users\Thinkbiz\AppData\Local\Temp\ipykernel_2548\562936487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Runtime"] = df["Runtime"].str.replace("min", "", regex=True).astype(float)

# %%
df.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime          float64
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# No_of_Votes        int64
# Gross             object
# Star_Cast         object
# type_name         object
# dtype: object

# %%
df.head(5)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A    142.0
# 1             The Godfather          1972           A    175.0
# 2           The Dark Knight          2008          UA    152.0
# 3    The Godfather: Part II          1974           A    202.0
# 4              12 Angry Men          1957           U     96.0
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df['Runtime'] = df['Runtime'].astype('int')
# Out:
# C:\Users\Thinkbiz\AppData\Local\Temp\ipykernel_2548\3208983419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Runtime'] = df['Runtime'].astype('int')

# %%
df.head(5)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A      142
# 1             The Godfather          1972           A      175
# 2           The Dark Knight          2008          UA      152
# 3    The Godfather: Part II          1974           A      202
# 4              12 Angry Men          1957           U       96
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df['total_time'] = pd.to_timedelta(df['Runtime'], unit='m').astype(str).str.replace('0 days ', '')
# Out:
# C:\Users\Thinkbiz\AppData\Local\Temp\ipykernel_2548\2118302867.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_time'] = pd.to_timedelta(df['Runtime'], unit='m').astype(str).str.replace('0 days ', '')

# %%
print(df[['Runtime', 'total_time']])
# Out:
#      Runtime total_time
# 0        142   02:22:00
# 1        175   02:55:00
# 2        152   02:32:00
# 3        202   03:22:00
# 4         96   01:36:00
# ..       ...        ...
# 995      115   01:55:00
# 996      201   03:21:00
# 997      118   01:58:00
# 998       97   01:37:00
# 999       86   01:26:00
#
# [843 rows x 2 columns]

# %%
df.head(2)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                Series_Title Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption          1994           A      142         Drama
# 1             The Godfather          1972           A      175  Crime, Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                Director  No_of_Votes         Gross  \
# 0        Frank Darabont      2343110   2,83,41,469
# 1  Francis Ford Coppola      1620367  13,49,66,411
#
#                                            Star_Cast type_name total_time
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...     Adult   02:22:00
# ...
